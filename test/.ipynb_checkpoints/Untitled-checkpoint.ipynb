# %%
import uproot
f = uproot.open("/data/fpiazza/ggHyyd/NtuplesWithBDTSkim/mc23e_ggHyyd_y_nominal_bdt.root")
f['nominal'].keys()
# Out:
# ['run',
#  'event',
#  'year',
#  'averageIntPerXing',
#  'actualIntPerXing',
#  'trigger_HLT_g50_tight_xe40_cell_xe70_pfopufit_80mTAC_EM22VHI',
#  'trigger_HLT_g50_tight_xe40_cell_xe70_pfopufit_80mTAC_L1eEM26M',
#  'mconly_weight',
#  'mconly_weights',
#  'pu_weight',
#  'jvt_weight',
#  'mu_SF_weight',
#  'ph_baseline_SF_weight',
#  'mu_SF_syst_MUON_EFF_BADMUON_SYS__1down',
#  'mu_SF_syst_MUON_EFF_BADMUON_SYS__1up',
#  'mu_SF_syst_MUON_EFF_ISO_STAT__1down',
#  'mu_SF_syst_MUON_EFF_ISO_STAT__1up',
#  'mu_SF_syst_MUON_EFF_ISO_SYS__1down',
#  'mu_SF_syst_MUON_EFF_ISO_SYS__1up',
#  'mu_SF_syst_MUON_EFF_RECO_STAT_LOWPT__1down',
#  'mu_SF_syst_MUON_EFF_RECO_STAT_LOWPT__1up',
#  'mu_SF_syst_MUON_EFF_RECO_STAT__1down',
#  'mu_SF_syst_MUON_EFF_RECO_STAT__1up',
#  'mu_SF_syst_MUON_EFF_RECO_SYS_LOWPT__1down',
#  'mu_SF_syst_MUON_EFF_RECO_SYS_LOWPT__1up',
#  'mu_SF_syst_MUON_EFF_RECO_SYS__1down',
#  'mu_SF_syst_MUON_EFF_RECO_SYS__1up',
#  'mu_SF_syst_MUON_EFF_TTVA_STAT__1down',
# ...
