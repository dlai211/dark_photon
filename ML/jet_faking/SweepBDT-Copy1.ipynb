# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import uproot, os, logging, json, random, wandb, shap
import awkward as ak
# import torch
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score, log_loss
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from scipy.stats import randint, uniform
from matplotlib.ticker import FormatStrFormatter
from collections import Counter

# ML model
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, log_loss, accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# Config
from bdt_config import sample_dict, zbi, getVarDict
from bdt_config import Vars, Vars2, Vars3, Vars_drop, Vars_plot
from bdt_config import variables, ntuple_name, ntuple_name_BDT

# Set up plot defaults
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 12.0,8.0  # Roughly 11 cm wde by 8 cm high
mpl.rcParams['font.size'] = 14.0 # Use 14 point font
sns.set(style="whitegrid")

# Check for gpu
# torch.cuda.is_available()

# %%
path = '/data/jlai/ntups/csv/jet_faking_BDT_input_basic.csv'
df = pd.read_csv(path)
df.describe()
# Out:
#             balance      BDTScore          dmet       dphi_jj  \
# count  3.299733e+06  3.299733e+06  3.299733e+06  3.299733e+06
# mean  -1.745489e+02  1.251438e-01 -1.663472e+03 -4.661989e+02
# std    3.835393e+02  1.348625e-01  1.103691e+04  4.983897e+02
# min   -9.990000e+02 -3.265468e-01 -1.712589e+05 -9.990000e+02
# 25%    9.546858e-01  8.068899e-03  0.000000e+00 -9.990000e+02
# 50%    1.283851e+00  1.647640e-01  0.000000e+00 -2.735425e+00
# 75%    2.922425e+00  2.371679e-01  0.000000e+00  1.512880e-01
# max    2.663229e+02  4.375860e-01  1.246841e+05  3.141591e+00
#
#        dphi_met_central_jet  dphi_met_phterm   dphi_met_ph  dphi_met_jetterm  \
# count          3.299733e+06     3.299733e+06  3.299733e+06      3.299733e+06
# mean          -1.848742e+02     4.027364e-01  2.738863e+00     -1.317202e+02
# std            3.894295e+02     6.314438e-01  6.313106e-01      3.400961e+02
# min           -9.990000e+02     0.000000e+00  1.167295e-02     -9.990000e+02
# 25%            4.369926e-02     5.094965e-02  2.728096e+00      2.204334e-01
# 50%            4.694079e-01     1.503438e-01  2.991172e+00      1.017702e+00
# 75%            2.476912e+00     4.133940e-01  3.090613e+00      2.863652e+00
# max            3.141592e+00     3.141593e+00  3.141593e+00      3.141593e+00
#
#        dphi_phterm_jetterm  dphi_ph_centraljet1  ...        metsig  \
# count         3.299733e+06         3.299733e+06  ...  3.299733e+06
# mean         -1.313245e+02        -1.842713e+02  ...  1.190690e+01
# std           3.402509e+02         3.897176e+02  ...  1.038910e+01
# min          -9.990000e+02        -9.990000e+02  ...  2.269695e-01
# 25%           5.477069e-01         3.878704e-01  ...  3.802686e+00
# 50%           2.089735e+00         2.023582e+00  ...  1.024574e+01
# 75%           3.105098e+00         3.039348e+00  ...  1.590387e+01
# max           3.141593e+00         3.141592e+00  ...  2.823775e+02
#
#           metsigres           met     met_noJVT     metplusph  \
# count  3.299733e+06  3.299733e+06  3.299733e+06  3.299733e+06
# mean   2.709180e+04  1.947991e+05  1.931356e+05  8.173447e+05
# std    2.307818e+04  1.623949e+05  1.632818e+05  8.139494e+05
# min    8.526343e+03  1.000000e+05  2.001940e+03  1.500329e+05
# 25%    1.057160e+04  1.177408e+05  1.162434e+05  2.738635e+05
# 50%    1.767059e+04  1.480967e+05  1.473863e+05  4.551331e+05
# 75%    3.643209e+04  2.160463e+05  2.158321e+05  1.013744e+06
# max    6.173285e+06  1.470684e+08  1.470684e+08  1.490961e+08
#
#        failJVT_jet_pt1       softerm  n_jet_central       weights  \
# count     3.299733e+06  3.299733e+06   3.299733e+06  3.299733e+06
# mean      8.082155e+03  9.400769e+03   1.752871e+00  6.037499e-01
# std       1.485037e+04  5.880428e+03   1.232225e+00  7.646898e+00
# min      -9.990000e+02  0.000000e+00   0.000000e+00 -9.143369e+01
# 25%      -9.990000e+02  4.993511e+03   1.000000e+00  1.026595e-04
# 50%      -9.990000e+02  8.329055e+03   2.000000e+00  1.174600e-02
# 75%       2.159741e+04  1.265224e+04   3.000000e+00  5.386639e-02
# max       5.999986e+04  1.022158e+05   4.000000e+00  1.221239e+04
#
#               label
# count  3.299733e+06
# mean   1.390112e-03
# std    3.725829e-02
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00
#
# [8 rows x 28 columns]

# %%
Vars2 = ['dphi_met_phterm', 'metsig', 'BDTScore', 'dphi_met_central_jet', 'dmet', 'jetterm', 'balance',  'weights', 'label', 'process']
Vars3 = ['ph_eta', 'ph_pt', 'failJVT_jet_pt1']

# %%
# === Data Perparation ===
df_Vars2 = df[Vars2].copy()
df_Vars3 = df[Vars3].copy()

df_Vars3.replace(-999, np.nan, inplace=True)
df_Vars3_inverted = 1 / df_Vars3.replace({0: np.nan})  # Avoid division by zero

df_ml_input = pd.concat([df_Vars2, df_Vars3_inverted], axis=1)
df_ml_input.replace(-999, np.nan, inplace=True)
print("Number of event with negative weights :", np.sum(df_ml_input.weights < 0))
df_ml_input["weights"] = df_ml_input["weights"].abs() # some of the weights are negative

display(df_ml_input.describe())

print("Number of nan in each variable: ")
print(df_ml_input.isna().sum())

# Define X (features) and y (labels)
# Vars_drop = ['weights', 'label', 'process']
X = df_ml_input.drop(Vars_drop, axis=1)
y = df_ml_input['label']
weights = df_ml_input['weights']

random_num = random.randint(1, 100)
print("random number: ", random_num)

X_train, X_test, y_train, y_test, sw_train, sw_test = train_test_split(
    X, y, weights, test_size=0.3, random_state=random_num, stratify=y)
# Out:
# Number of event with negative weights : 218306
#        dphi_met_phterm        metsig      BDTScore  dphi_met_central_jet  \
# count     3.299733e+06  3.299733e+06  3.299733e+06          2.685312e+06
# mean      4.027364e-01  1.190690e+01  1.251438e-01          1.404322e+00
# std       6.314438e-01  1.038910e+01  1.348625e-01          1.176454e+00
# min       0.000000e+00  2.269695e-01 -3.265468e-01          1.192093e-07
# 25%       5.094965e-02  3.802686e+00  8.068899e-03          1.804473e-01
# 50%       1.503438e-01  1.024574e+01  1.647640e-01          1.257375e+00
# 75%       4.133940e-01  1.590387e+01  2.371679e-01          2.651747e+00
# max       3.141593e+00  2.823775e+02  4.375860e-01          3.141592e+00
#
#                dmet       jetterm       balance       weights         label  \
# count  3.299732e+06  3.299733e+06  2.712769e+06  3.299733e+06  3.299733e+06
# mean  -1.663472e+03  5.232991e+05  3.838187e+00  6.196378e-01  1.390112e-03
# std    1.103691e+04  7.927709e+05  6.130255e+00  7.645627e+00  3.725829e-02
# min   -1.712589e+05  0.000000e+00  3.173358e-02  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  3.469025e+04  1.127429e+00  1.428430e-03  0.000000e+00
# 50%    0.000000e+00  1.292316e+05  1.535997e+00  1.519263e-02  0.000000e+00
# 75%    0.000000e+00  6.824688e+05  3.771265e+00  6.219316e-02  0.000000e+00
# max    1.246841e+05  5.019984e+06  2.663229e+02  1.221239e+04  1.000000e+00
#
#              ph_eta         ph_pt  failJVT_jet_pt1
# count  3.299733e+06  3.299733e+06    977687.000000
# mean   4.619389e+00  5.638744e-06         0.000036
# std    4.657088e+02  4.934680e-06         0.000009
# min    3.966429e-01  1.995369e-07         0.000017
# 25%    7.511125e-01  1.213521e-06         0.000030
# 50%    1.271312e+00  4.487454e-06         0.000038
# 75%    2.644231e+00  8.563076e-06         0.000044
# max    8.314374e+05  1.999992e-05         0.000050
# Number of nan in each variable:
# dphi_met_phterm               0
# metsig                        0
# BDTScore                      0
# dphi_met_central_jet     614421
# dmet                          1
# jetterm                       0
# balance                  586964
# weights                       0
# label                         0
# process                       0
# ph_eta                        0
# ph_pt                         0
# failJVT_jet_pt1         2322046
# dtype: int64
# random number:  59

# %%
# === Sweep Config ===
sweep_config = {
    "method": "random", # "bayes" or "random"
    "metric": {"name": "Test ROC AUC", "goal": "maximize"},
    "parameters": {
        "max_depth": {"min": 3, "max": 10, "distribution": "int_uniform"},
        "learning_rate": {"min": 0.0001, "max": 0.1},
        "n_estimators": {"min": 100, "max": 900, "distribution": "int_uniform"},
        "subsample": {"min": 0.2, "max": 0.8},
        "gamma": {"min": 0.1, "max": 1.0}
    }
}
def compute_significance(df, score_column="bdtscore", cut=0.01):
    sig = df[(df["label"] == 1) & (df[score_column] >= cut)]["weights"].sum()
    bkg = df[(df["label"] == 0) & (df[score_column] >= cut)]["weights"].sum()
    return sig / np.sqrt(bkg) if bkg > 0 else 0, sig/df[(df["label"] == 1)]["weights"].sum()

def sweep_train():
    with wandb.init() as run:
        config = run.config

        model = XGBClassifier(
            tree_method='hist',
            device='cuda',
            max_depth=config.max_depth,
            learning_rate=config.learning_rate,
            n_estimators=config.n_estimators,
            subsample=config.subsample,
            gamma=config.gamma,
            early_stopping_rounds=10,
            eval_metric=['logloss', 'error', 'auc'],
            missing=np.nan,
            random_state=random_num
        )

        model.fit(
            X_train, y_train,
            sample_weight=sw_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            sample_weight_eval_set=[sw_train, sw_test],
            verbose=False
        )

        y_test_pred = model.predict_proba(X_test.to_numpy())[:, 1]
        test_auc = roc_auc_score(y_test, y_test_pred, sample_weight=sw_test)

        df_tmp = df_ml_input.copy()
        df_tmp["bdtscore2"] = model.predict_proba(df_ml_input.drop(Vars_drop, axis=1))[:, 1]

        best_significance = 0
        best_acceptance = 0
        best_cut = 0
        for cut in np.arange(0, 0.15, 0.01):
            sig, acc = compute_significance(df_tmp, score_column="bdtscore2", cut=cut)
            if sig > best_significance:
                best_significance = sig
                best_acceptance = acc
                best_cut = cut

        wandb.log({
            "Test ROC AUC": test_auc,
            "Max S/sqrt(B)": best_significance,
            "Acceptance": best_acceptance,
            "bdtscore2 cut": best_cut
        })

        results = model.evals_result()
        train_loss = results['validation_0']['logloss']
        test_loss = results['validation_1']['logloss']

        for i, (train_l, test_l) in enumerate(zip(train_loss, test_loss)):
            wandb.log({
                "train_logloss": train_l,
                "test_logloss": test_l,
                "iteration": i
            })

# %%
# === Run Sweep ===
sweep_id = wandb.sweep(sweep_config, project="Dark_ph_BDT_Sweep_Reduced")
wandb.agent(sweep_id, function=sweep_train, count=30)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: 3k6bfaco
# Sweep URL: https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco
# wandb: Agent Starting Run: 104bqtnz with config:
# wandb: 	gamma: 0.867683426847459
# wandb: 	learning_rate: 0.01223426039460053
# wandb: 	max_depth: 5
# wandb: 	n_estimators: 772
# wandb: 	subsample: 0.7462925567621774
# wandb: Currently logged in as: dlai211 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060055-104bqtnz</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/104bqtnz' target="_blank">swept-sweep-1</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/104bqtnz' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/104bqtnz</a>
# [06:00:58] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>███▇▇▇▇▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.35155</td></tr><tr><td>Max S/sqrt(B)</td><td>2.49201</td></tr><tr><td>Test ROC AUC</td><td>0.87712</td></tr><tr><td>bdtscore2 cut</td><td>0.07</td></tr><tr><td>iteration</td><td>60</td></tr><tr><td>test_logloss</td><td>0.05894</td></tr><tr><td>train_logloss</td><td>0.05893</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swept-sweep-1</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/104bqtnz' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/104bqtnz</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060055-104bqtnz/logs</code>
# wandb: Agent Starting Run: 6a9zvsi3 with config:
# wandb: 	gamma: 0.3664670541912113
# wandb: 	learning_rate: 0.009353517376952333
# wandb: 	max_depth: 8
# wandb: 	n_estimators: 595
# wandb: 	subsample: 0.5112728054592456
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060106-6a9zvsi3</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6a9zvsi3' target="_blank">confused-sweep-2</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6a9zvsi3' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6a9zvsi3</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>test_logloss</td><td>██▇▇▆▆▆▅▅▄▄▄▃▃▂▂▂▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▆▆▆▅▅▄▄▄▃▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.52272</td></tr><tr><td>Max S/sqrt(B)</td><td>2.19558</td></tr><tr><td>Test ROC AUC</td><td>0.8146</td></tr><tr><td>bdtscore2 cut</td><td>0.11</td></tr><tr><td>iteration</td><td>18</td></tr><tr><td>test_logloss</td><td>0.10575</td></tr><tr><td>train_logloss</td><td>0.10574</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">confused-sweep-2</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6a9zvsi3' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6a9zvsi3</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060106-6a9zvsi3/logs</code>
# wandb: Agent Starting Run: pldq3rda with config:
# wandb: 	gamma: 0.5028368127575198
# wandb: 	learning_rate: 0.07883154583218593
# wandb: 	max_depth: 10
# wandb: 	n_estimators: 307
# wandb: 	subsample: 0.365221645242772
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060116-pldq3rda</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pldq3rda' target="_blank">solar-sweep-3</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pldq3rda' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pldq3rda</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>█▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▃▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.31578</td></tr><tr><td>Max S/sqrt(B)</td><td>3.8861</td></tr><tr><td>Test ROC AUC</td><td>0.98108</td></tr><tr><td>bdtscore2 cut</td><td>0.05</td></tr><tr><td>iteration</td><td>191</td></tr><tr><td>test_logloss</td><td>0.00126</td></tr><tr><td>train_logloss</td><td>0.00118</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">solar-sweep-3</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pldq3rda' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pldq3rda</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060116-pldq3rda/logs</code>
# wandb: Agent Starting Run: 6ppmskne with config:
# wandb: 	gamma: 0.906143481251818
# wandb: 	learning_rate: 0.011749567780146882
# wandb: 	max_depth: 5
# wandb: 	n_estimators: 199
# wandb: 	subsample: 0.32658573836525795
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060126-6ppmskne</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6ppmskne' target="_blank">fanciful-sweep-4</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6ppmskne' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6ppmskne</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_logloss</td><td>███▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>███▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.23817</td></tr><tr><td>Max S/sqrt(B)</td><td>2.31053</td></tr><tr><td>Test ROC AUC</td><td>0.83406</td></tr><tr><td>bdtscore2 cut</td><td>0.08</td></tr><tr><td>iteration</td><td>57</td></tr><tr><td>test_logloss</td><td>0.06295</td></tr><tr><td>train_logloss</td><td>0.06294</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fanciful-sweep-4</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6ppmskne' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6ppmskne</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060126-6ppmskne/logs</code>
# wandb: Agent Starting Run: mn822f4g with config:
# wandb: 	gamma: 0.3516590023659488
# wandb: 	learning_rate: 0.093715957578858
# wandb: 	max_depth: 5
# wandb: 	n_estimators: 170
# wandb: 	subsample: 0.5661862959653527
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060136-mn822f4g</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/mn822f4g' target="_blank">cool-sweep-5</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/mn822f4g' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/mn822f4g</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>test_logloss</td><td>█▇▆▅▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▇▅▅▄▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.52115</td></tr><tr><td>Max S/sqrt(B)</td><td>3.4821</td></tr><tr><td>Test ROC AUC</td><td>0.98068</td></tr><tr><td>bdtscore2 cut</td><td>0.02</td></tr><tr><td>iteration</td><td>162</td></tr><tr><td>test_logloss</td><td>0.00127</td></tr><tr><td>train_logloss</td><td>0.00122</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cool-sweep-5</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/mn822f4g' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/mn822f4g</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060136-mn822f4g/logs</code>
# wandb: Agent Starting Run: vszbyrsj with config:
# wandb: 	gamma: 0.25097838697183655
# wandb: 	learning_rate: 0.003973323673888102
# wandb: 	max_depth: 5
# wandb: 	n_estimators: 879
# wandb: 	subsample: 0.7321446099076183
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060147-vszbyrsj</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/vszbyrsj' target="_blank">fluent-sweep-6</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/vszbyrsj' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/vszbyrsj</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>test_logloss</td><td>██▇▇▆▆▆▅▅▄▄▄▃▃▃▂▂▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▆▆▆▅▅▄▄▄▃▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>1</td></tr><tr><td>Max S/sqrt(B)</td><td>0.32308</td></tr><tr><td>Test ROC AUC</td><td>0.87772</td></tr><tr><td>bdtscore2 cut</td><td>0</td></tr><tr><td>iteration</td><td>18</td></tr><tr><td>test_logloss</td><td>0.11772</td></tr><tr><td>train_logloss</td><td>0.11772</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fluent-sweep-6</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/vszbyrsj' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/vszbyrsj</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060147-vszbyrsj/logs</code>
# wandb: Agent Starting Run: pdas8cce with config:
# wandb: 	gamma: 0.7616132257071334
# wandb: 	learning_rate: 0.03569020222986736
# wandb: 	max_depth: 10
# wandb: 	n_estimators: 467
# wandb: 	subsample: 0.33404730220915124
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060157-pdas8cce</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pdas8cce' target="_blank">floral-sweep-7</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pdas8cce' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pdas8cce</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>██▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.21267</td></tr><tr><td>Max S/sqrt(B)</td><td>2.423</td></tr><tr><td>Test ROC AUC</td><td>0.83413</td></tr><tr><td>bdtscore2 cut</td><td>0.08</td></tr><tr><td>iteration</td><td>26</td></tr><tr><td>test_logloss</td><td>0.04731</td></tr><tr><td>train_logloss</td><td>0.04731</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">floral-sweep-7</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pdas8cce' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/pdas8cce</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060157-pdas8cce/logs</code>
# wandb: Agent Starting Run: avtskdca with config:
# wandb: 	gamma: 0.22933360476861
# wandb: 	learning_rate: 0.030204814041508224
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 313
# wandb: 	subsample: 0.37075569898029914
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060207-avtskdca</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/avtskdca' target="_blank">sweepy-sweep-8</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/avtskdca' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/avtskdca</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>█▆▅▄▄▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▇▇▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.46446</td></tr><tr><td>Max S/sqrt(B)</td><td>3.1802</td></tr><tr><td>Test ROC AUC</td><td>0.97758</td></tr><tr><td>bdtscore2 cut</td><td>0.02</td></tr><tr><td>iteration</td><td>312</td></tr><tr><td>test_logloss</td><td>0.0013</td></tr><tr><td>train_logloss</td><td>0.0013</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweepy-sweep-8</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/avtskdca' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/avtskdca</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060207-avtskdca/logs</code>
# wandb: Agent Starting Run: 6vnofb93 with config:
# wandb: 	gamma: 0.10354362585011546
# wandb: 	learning_rate: 0.060848680899859134
# wandb: 	max_depth: 8
# wandb: 	n_estimators: 118
# wandb: 	subsample: 0.2902250148341254
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060218-6vnofb93</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6vnofb93' target="_blank">summer-sweep-9</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6vnofb93' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6vnofb93</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇█████</td></tr><tr><td>test_logloss</td><td>█▆▅▅▄▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>██▆▄▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.40323</td></tr><tr><td>Max S/sqrt(B)</td><td>3.54123</td></tr><tr><td>Test ROC AUC</td><td>0.97344</td></tr><tr><td>bdtscore2 cut</td><td>0.03</td></tr><tr><td>iteration</td><td>117</td></tr><tr><td>test_logloss</td><td>0.00136</td></tr><tr><td>train_logloss</td><td>0.00133</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">summer-sweep-9</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6vnofb93' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6vnofb93</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060218-6vnofb93/logs</code>
# wandb: Agent Starting Run: 4jcc3ums with config:
# wandb: 	gamma: 0.24253760887786957
# wandb: 	learning_rate: 0.036394582389545536
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 804
# wandb: 	subsample: 0.45398157578452714
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060228-4jcc3ums</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/4jcc3ums' target="_blank">splendid-sweep-10</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/4jcc3ums' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/4jcc3ums</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_logloss</td><td>██▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.48961</td></tr><tr><td>Max S/sqrt(B)</td><td>2.15631</td></tr><tr><td>Test ROC AUC</td><td>0.87689</td></tr><tr><td>bdtscore2 cut</td><td>0.06</td></tr><tr><td>iteration</td><td>30</td></tr><tr><td>test_logloss</td><td>0.04016</td></tr><tr><td>train_logloss</td><td>0.04015</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">splendid-sweep-10</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/4jcc3ums' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/4jcc3ums</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060228-4jcc3ums/logs</code>
# wandb: Agent Starting Run: 6tfsgkem with config:
# wandb: 	gamma: 0.6623667473178169
# wandb: 	learning_rate: 0.059217225209607
# wandb: 	max_depth: 7
# wandb: 	n_estimators: 750
# wandb: 	subsample: 0.5775255500186753
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060238-6tfsgkem</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6tfsgkem' target="_blank">fiery-sweep-11</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6tfsgkem' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6tfsgkem</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>█▆▆▅▅▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▅▄▃▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.4215</td></tr><tr><td>Max S/sqrt(B)</td><td>3.57573</td></tr><tr><td>Test ROC AUC</td><td>0.98046</td></tr><tr><td>bdtscore2 cut</td><td>0.03</td></tr><tr><td>iteration</td><td>233</td></tr><tr><td>test_logloss</td><td>0.00127</td></tr><tr><td>train_logloss</td><td>0.00121</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fiery-sweep-11</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6tfsgkem' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/6tfsgkem</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060238-6tfsgkem/logs</code>
# wandb: Agent Starting Run: uwysed7p with config:
# wandb: 	gamma: 0.17092411091105525
# wandb: 	learning_rate: 0.08799104193998067
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 851
# wandb: 	subsample: 0.5737879849966937
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060248-uwysed7p</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/uwysed7p' target="_blank">trim-sweep-12</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/uwysed7p' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/uwysed7p</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_logloss</td><td>█▆▅▅▄▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.42805</td></tr><tr><td>Max S/sqrt(B)</td><td>3.60279</td></tr><tr><td>Test ROC AUC</td><td>0.98111</td></tr><tr><td>bdtscore2 cut</td><td>0.03</td></tr><tr><td>iteration</td><td>262</td></tr><tr><td>test_logloss</td><td>0.00126</td></tr><tr><td>train_logloss</td><td>0.00121</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">trim-sweep-12</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/uwysed7p' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/uwysed7p</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060248-uwysed7p/logs</code>
# wandb: Agent Starting Run: kdu1xruz with config:
# wandb: 	gamma: 0.826248604210832
# wandb: 	learning_rate: 0.03602263912455945
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 857
# wandb: 	subsample: 0.22790678634131936
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060259-kdu1xruz</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/kdu1xruz' target="_blank">restful-sweep-13</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/kdu1xruz' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/kdu1xruz</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_logloss</td><td>██▇▇▇▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▇▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.38779</td></tr><tr><td>Max S/sqrt(B)</td><td>2.36645</td></tr><tr><td>Test ROC AUC</td><td>0.83408</td></tr><tr><td>bdtscore2 cut</td><td>0.06</td></tr><tr><td>iteration</td><td>32</td></tr><tr><td>test_logloss</td><td>0.03782</td></tr><tr><td>train_logloss</td><td>0.03782</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">restful-sweep-13</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/kdu1xruz' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/kdu1xruz</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060259-kdu1xruz/logs</code>
# wandb: Agent Starting Run: j5gjkjn7 with config:
# wandb: 	gamma: 0.3389900368937
# wandb: 	learning_rate: 0.030695284300420327
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 668
# wandb: 	subsample: 0.20410936695840717
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060309-j5gjkjn7</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/j5gjkjn7' target="_blank">dazzling-sweep-14</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/j5gjkjn7' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/j5gjkjn7</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>██▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.34431</td></tr><tr><td>Max S/sqrt(B)</td><td>2.21606</td></tr><tr><td>Test ROC AUC</td><td>0.83393</td></tr><tr><td>bdtscore2 cut</td><td>0.08</td></tr><tr><td>iteration</td><td>25</td></tr><tr><td>test_logloss</td><td>0.05591</td></tr><tr><td>train_logloss</td><td>0.0559</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dazzling-sweep-14</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/j5gjkjn7' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/j5gjkjn7</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060309-j5gjkjn7/logs</code>
# wandb: Agent Starting Run: nw2lge84 with config:
# wandb: 	gamma: 0.6667861571260243
# wandb: 	learning_rate: 0.014186996744017962
# wandb: 	max_depth: 7
# wandb: 	n_estimators: 595
# wandb: 	subsample: 0.5267531409088588
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060319-nw2lge84</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/nw2lge84' target="_blank">lyric-sweep-15</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/nw2lge84' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/nw2lge84</a>
# ...
# wandb: 	learning_rate: 0.017825031355462994
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 205
# wandb: 	subsample: 0.6935659661378322
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060512-y59wt3ok</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y59wt3ok' target="_blank">rural-sweep-26</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y59wt3ok' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y59wt3ok</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>██▇▇▆▅▅▅▅▅▄▄▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>███▇▇▆▆▆▆▅▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.41045</td></tr><tr><td>Max S/sqrt(B)</td><td>2.6393</td></tr><tr><td>Test ROC AUC</td><td>0.9187</td></tr><tr><td>bdtscore2 cut</td><td>0.02</td></tr><tr><td>iteration</td><td>204</td></tr><tr><td>test_logloss</td><td>0.00429</td></tr><tr><td>train_logloss</td><td>0.00428</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rural-sweep-26</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y59wt3ok' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y59wt3ok</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060512-y59wt3ok/logs</code>
# wandb: Agent Starting Run: ogai1hl1 with config:
# wandb: 	gamma: 0.5070897604788732
# wandb: 	learning_rate: 0.008945921518625709
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 849
# wandb: 	subsample: 0.7728625253635486
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060522-ogai1hl1</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/ogai1hl1' target="_blank">ancient-sweep-27</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/ogai1hl1' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/ogai1hl1</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>test_logloss</td><td>██▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▂▂▂▂▁▁</td></tr><tr><td>train_logloss</td><td>██▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▂▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>1</td></tr><tr><td>Max S/sqrt(B)</td><td>0.32308</td></tr><tr><td>Test ROC AUC</td><td>0.87729</td></tr><tr><td>bdtscore2 cut</td><td>0</td></tr><tr><td>iteration</td><td>23</td></tr><tr><td>test_logloss</td><td>0.10174</td></tr><tr><td>train_logloss</td><td>0.10173</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ancient-sweep-27</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/ogai1hl1' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/ogai1hl1</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060522-ogai1hl1/logs</code>
# wandb: Agent Starting Run: a8kipii7 with config:
# wandb: 	gamma: 0.613933624040347
# wandb: 	learning_rate: 0.0472640835288556
# wandb: 	max_depth: 6
# wandb: 	n_estimators: 711
# wandb: 	subsample: 0.2650247448282007
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060533-a8kipii7</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/a8kipii7' target="_blank">gallant-sweep-28</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/a8kipii7' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/a8kipii7</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇██</td></tr><tr><td>test_logloss</td><td>█▆▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▆▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.38322</td></tr><tr><td>Max S/sqrt(B)</td><td>3.41977</td></tr><tr><td>Test ROC AUC</td><td>0.97866</td></tr><tr><td>bdtscore2 cut</td><td>0.03</td></tr><tr><td>iteration</td><td>246</td></tr><tr><td>test_logloss</td><td>0.00128</td></tr><tr><td>train_logloss</td><td>0.00126</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gallant-sweep-28</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/a8kipii7' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/a8kipii7</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060533-a8kipii7/logs</code>
# wandb: Agent Starting Run: wris8ekw with config:
# wandb: 	gamma: 0.4331868045229737
# wandb: 	learning_rate: 0.015107465332345344
# wandb: 	max_depth: 10
# wandb: 	n_estimators: 266
# wandb: 	subsample: 0.28391177119397354
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060543-wris8ekw</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/wris8ekw' target="_blank">morning-sweep-29</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/wris8ekw' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/wris8ekw</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_logloss</td><td>██▇▇▇▇▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>███▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.2884</td></tr><tr><td>Max S/sqrt(B)</td><td>2.63969</td></tr><tr><td>Test ROC AUC</td><td>0.83428</td></tr><tr><td>bdtscore2 cut</td><td>0.07</td></tr><tr><td>iteration</td><td>58</td></tr><tr><td>test_logloss</td><td>0.05092</td></tr><tr><td>train_logloss</td><td>0.05091</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">morning-sweep-29</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/wris8ekw' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/wris8ekw</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060543-wris8ekw/logs</code>
# wandb: Agent Starting Run: y1z1j1is with config:
# wandb: 	gamma: 0.4918699484226722
# wandb: 	learning_rate: 0.02884575921548908
# wandb: 	max_depth: 6
# wandb: 	n_estimators: 176
# wandb: 	subsample: 0.37089531918312246
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250630_060553-y1z1j1is</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y1z1j1is' target="_blank">twilight-sweep-30</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a>
#  View sweep at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/sweeps/3k6bfaco</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y1z1j1is' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y1z1j1is</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>▁</td></tr><tr><td>Max S/sqrt(B)</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>bdtscore2 cut</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>test_logloss</td><td>███▇▆▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▇▇▆▆▅▅▄▄▄▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acceptance</td><td>0.4594</td></tr><tr><td>Max S/sqrt(B)</td><td>3.20058</td></tr><tr><td>Test ROC AUC</td><td>0.93552</td></tr><tr><td>bdtscore2 cut</td><td>0.02</td></tr><tr><td>iteration</td><td>175</td></tr><tr><td>test_logloss</td><td>0.00198</td></tr><tr><td>train_logloss</td><td>0.00198</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">twilight-sweep-30</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y1z1j1is' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced/runs/y1z1j1is</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced' target="_blank">https://wandb.ai/dlai211/Dark_ph_BDT_Sweep_Reduced</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250630_060553-y1z1j1is/logs</code>

# %%
# === Model with best parameters ===
model = XGBClassifier(
    tree_method='hist',
    device='cuda',
    max_depth=8,
    learning_rate=0.0425,
    n_estimators=532,
    subsample=0.5954,
    gamma=0.2643,
    eval_metric=["auc"],
    early_stopping_rounds=10,
    use_label_encoder=False,
    missing=np.nan
)

model.fit(
    X_train, y_train,
    sample_weight=sw_train,
    eval_set=[(X_test, y_test)],
    sample_weight_eval_set=[sw_test],
    verbose=True
)

# === Evaluation ===
y_test_pred_proba = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_test_pred_proba, sample_weight=sw_test)
print(f"Test ROC AUC: {auc:.4f}")
# Out:
# [0]	validation_0-auc:0.77936
# [1]	validation_0-auc:0.80739
# [2]	validation_0-auc:0.80740
# [3]	validation_0-auc:0.80739
# [4]	validation_0-auc:0.80743
# [5]	validation_0-auc:0.80742
# [00:20:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
# [6]	validation_0-auc:0.80742
# [7]	validation_0-auc:0.80743
# [8]	validation_0-auc:0.87176
# [9]	validation_0-auc:0.87176
# [10]	validation_0-auc:0.87175
# [11]	validation_0-auc:0.87148
# [12]	validation_0-auc:0.87150
# [13]	validation_0-auc:0.87187
# [14]	validation_0-auc:0.87184
# [15]	validation_0-auc:0.87180
# [16]	validation_0-auc:0.87177
# [17]	validation_0-auc:0.87174
# [18]	validation_0-auc:0.87211
# [19]	validation_0-auc:0.87210
# [20]	validation_0-auc:0.87207
# [21]	validation_0-auc:0.87209
# [22]	validation_0-auc:0.87204
# [23]	validation_0-auc:0.87218
# [24]	validation_0-auc:0.87220
# [25]	validation_0-auc:0.87219
# [26]	validation_0-auc:0.87215
# [27]	validation_0-auc:0.87227
# [28]	validation_0-auc:0.87245
# [29]	validation_0-auc:0.87246
# [30]	validation_0-auc:0.87253
# [31]	validation_0-auc:0.87259
# [32]	validation_0-auc:0.87263
# [33]	validation_0-auc:0.87279
# [34]	validation_0-auc:0.87282
# [35]	validation_0-auc:0.87283
# [36]	validation_0-auc:0.87293
# [37]	validation_0-auc:0.87296
# [38]	validation_0-auc:0.87299
# [39]	validation_0-auc:0.88013
# [40]	validation_0-auc:0.88023
# [41]	validation_0-auc:0.88024
# [42]	validation_0-auc:0.90714
# [43]	validation_0-auc:0.90716
# [44]	validation_0-auc:0.90717
# [45]	validation_0-auc:0.90743
# [46]	validation_0-auc:0.90747
# [47]	validation_0-auc:0.90750
# [48]	validation_0-auc:0.90757
# [49]	validation_0-auc:0.90763
# [50]	validation_0-auc:0.90763
# [51]	validation_0-auc:0.90763
# [52]	validation_0-auc:0.90781
# [53]	validation_0-auc:0.90782
# [54]	validation_0-auc:0.90792
# [55]	validation_0-auc:0.90800
# [56]	validation_0-auc:0.90811
# [57]	validation_0-auc:0.90811
# [58]	validation_0-auc:0.90815
# [59]	validation_0-auc:0.90821
# [60]	validation_0-auc:0.90825
# [61]	validation_0-auc:0.90826
# [62]	validation_0-auc:0.90829
# [63]	validation_0-auc:0.90830
# [64]	validation_0-auc:0.90841
# [65]	validation_0-auc:0.90847
# [66]	validation_0-auc:0.90848
# [67]	validation_0-auc:0.90851
# [68]	validation_0-auc:0.90851
# [69]	validation_0-auc:0.91436
# [70]	validation_0-auc:0.91432
# [71]	validation_0-auc:0.91729
# [72]	validation_0-auc:0.91730
# [73]	validation_0-auc:0.91729
# [74]	validation_0-auc:0.91733
# [75]	validation_0-auc:0.91742
# [76]	validation_0-auc:0.91749
# [77]	validation_0-auc:0.91754
# [78]	validation_0-auc:0.91765
# [79]	validation_0-auc:0.91769
# [80]	validation_0-auc:0.91775
# [81]	validation_0-auc:0.91777
# [82]	validation_0-auc:0.91782
# [83]	validation_0-auc:0.91786
# [84]	validation_0-auc:0.91787
# [85]	validation_0-auc:0.91791
# [86]	validation_0-auc:0.91793
# [87]	validation_0-auc:0.91793
# [88]	validation_0-auc:0.91797
# [89]	validation_0-auc:0.91799
# [90]	validation_0-auc:0.91800
# [91]	validation_0-auc:0.91804
# [92]	validation_0-auc:0.91808
# [93]	validation_0-auc:0.91808
# [94]	validation_0-auc:0.91810
# [95]	validation_0-auc:0.91815
# [96]	validation_0-auc:0.91816
# [97]	validation_0-auc:0.91817
# [98]	validation_0-auc:0.91818
# [99]	validation_0-auc:0.91820
# [100]	validation_0-auc:0.91822
# [101]	validation_0-auc:0.91825
# [102]	validation_0-auc:0.92345
# [103]	validation_0-auc:0.92345
# [104]	validation_0-auc:0.92346
# [105]	validation_0-auc:0.92352
# [106]	validation_0-auc:0.92354
# [107]	validation_0-auc:0.92356
# [108]	validation_0-auc:0.92358
# [109]	validation_0-auc:0.92472
# [110]	validation_0-auc:0.92480
# [111]	validation_0-auc:0.92486
# [112]	validation_0-auc:0.92492
# [113]	validation_0-auc:0.92496
# [114]	validation_0-auc:0.92502
# [115]	validation_0-auc:0.92508
# [116]	validation_0-auc:0.93014
# [117]	validation_0-auc:0.93016
# [118]	validation_0-auc:0.93021
# [119]	validation_0-auc:0.93022
# [120]	validation_0-auc:0.93022
# [121]	validation_0-auc:0.93023
# [122]	validation_0-auc:0.93024
# [123]	validation_0-auc:0.93027
# [124]	validation_0-auc:0.93029
# [125]	validation_0-auc:0.93078
# [126]	validation_0-auc:0.93083
# [127]	validation_0-auc:0.93083
# [128]	validation_0-auc:0.93083
# [129]	validation_0-auc:0.93083
# [130]	validation_0-auc:0.93095
# [131]	validation_0-auc:0.94916
# [132]	validation_0-auc:0.94915
# [133]	validation_0-auc:0.94910
# [134]	validation_0-auc:0.94910
# [135]	validation_0-auc:0.94908
# [136]	validation_0-auc:0.94982
# [137]	validation_0-auc:0.95575
# [138]	validation_0-auc:0.95571
# [139]	validation_0-auc:0.95570
# [140]	validation_0-auc:0.95875
# [141]	validation_0-auc:0.95858
# [142]	validation_0-auc:0.95891
# [143]	validation_0-auc:0.95912
# [144]	validation_0-auc:0.95958
# [145]	validation_0-auc:0.95974
# [146]	validation_0-auc:0.96340
# [147]	validation_0-auc:0.96522
# [148]	validation_0-auc:0.96594
# [149]	validation_0-auc:0.96607
# [150]	validation_0-auc:0.96653
# [151]	validation_0-auc:0.96667
# [152]	validation_0-auc:0.96711
# [153]	validation_0-auc:0.96741
# [154]	validation_0-auc:0.96750
# [155]	validation_0-auc:0.96778
# [156]	validation_0-auc:0.96814
# [157]	validation_0-auc:0.96824
# [158]	validation_0-auc:0.96837
# [159]	validation_0-auc:0.96841
# [160]	validation_0-auc:0.96874
# [161]	validation_0-auc:0.96866
# [162]	validation_0-auc:0.96876
# [163]	validation_0-auc:0.96877
# [164]	validation_0-auc:0.96899
# [165]	validation_0-auc:0.96897
# [166]	validation_0-auc:0.96901
# [167]	validation_0-auc:0.96915
# [168]	validation_0-auc:0.96921
# [169]	validation_0-auc:0.96934
# [170]	validation_0-auc:0.96952
# [171]	validation_0-auc:0.96961
# [172]	validation_0-auc:0.96970
# [173]	validation_0-auc:0.96968
# [174]	validation_0-auc:0.96983
# [175]	validation_0-auc:0.96974
# [176]	validation_0-auc:0.96978
# [177]	validation_0-auc:0.96997
# [178]	validation_0-auc:0.96995
# [179]	validation_0-auc:0.96990
# [180]	validation_0-auc:0.97020
# [181]	validation_0-auc:0.97053
# [182]	validation_0-auc:0.97057
# [183]	validation_0-auc:0.97093
# [184]	validation_0-auc:0.97113
# [185]	validation_0-auc:0.97118
# [186]	validation_0-auc:0.97132
# [187]	validation_0-auc:0.97140
# [188]	validation_0-auc:0.97144
# [189]	validation_0-auc:0.97151
# [190]	validation_0-auc:0.97160
# [191]	validation_0-auc:0.97179
# [192]	validation_0-auc:0.97194
# [193]	validation_0-auc:0.97201
# [194]	validation_0-auc:0.97200
# [195]	validation_0-auc:0.97191
# [196]	validation_0-auc:0.97207
# [197]	validation_0-auc:0.97228
# [198]	validation_0-auc:0.97231
# [199]	validation_0-auc:0.97232
# [200]	validation_0-auc:0.97252
# [201]	validation_0-auc:0.97278
# [202]	validation_0-auc:0.97306
# [203]	validation_0-auc:0.97335
# [204]	validation_0-auc:0.97342
# [205]	validation_0-auc:0.97358
# [206]	validation_0-auc:0.97392
# [207]	validation_0-auc:0.97396
# [208]	validation_0-auc:0.97400
# [209]	validation_0-auc:0.97417
# [210]	validation_0-auc:0.97417
# [211]	validation_0-auc:0.97428
# [212]	validation_0-auc:0.97434
# [213]	validation_0-auc:0.97439
# [214]	validation_0-auc:0.97437
# [215]	validation_0-auc:0.97458
# [216]	validation_0-auc:0.97458
# [217]	validation_0-auc:0.97472
# [218]	validation_0-auc:0.97479
# [219]	validation_0-auc:0.97485
# [220]	validation_0-auc:0.97495
# [221]	validation_0-auc:0.97502
# [222]	validation_0-auc:0.97505
# [223]	validation_0-auc:0.97520
# [224]	validation_0-auc:0.97541
# [225]	validation_0-auc:0.97548
# [226]	validation_0-auc:0.97548
# [227]	validation_0-auc:0.97564
# [228]	validation_0-auc:0.97578
# [229]	validation_0-auc:0.97588
# [230]	validation_0-auc:0.97592
# [231]	validation_0-auc:0.97594
# [232]	validation_0-auc:0.97601
# [233]	validation_0-auc:0.97603
# [234]	validation_0-auc:0.97614
# [235]	validation_0-auc:0.97616
# [236]	validation_0-auc:0.97627
# [237]	validation_0-auc:0.97629
# [238]	validation_0-auc:0.97645
# [239]	validation_0-auc:0.97644
# [240]	validation_0-auc:0.97655
# [241]	validation_0-auc:0.97668
# [242]	validation_0-auc:0.97666
# [243]	validation_0-auc:0.97668
# [244]	validation_0-auc:0.97673
# [245]	validation_0-auc:0.97686
# [246]	validation_0-auc:0.97692
# [247]	validation_0-auc:0.97698
# [248]	validation_0-auc:0.97700
# [249]	validation_0-auc:0.97708
# [250]	validation_0-auc:0.97713
# [251]	validation_0-auc:0.97710
# [252]	validation_0-auc:0.97714
# [253]	validation_0-auc:0.97729
# [254]	validation_0-auc:0.97736
# [255]	validation_0-auc:0.97740
# [256]	validation_0-auc:0.97735
# [257]	validation_0-auc:0.97750
# [258]	validation_0-auc:0.97751
# [259]	validation_0-auc:0.97756
# [260]	validation_0-auc:0.97758
# [261]	validation_0-auc:0.97761
# [262]	validation_0-auc:0.97763
# [263]	validation_0-auc:0.97765
# [264]	validation_0-auc:0.97763
# [265]	validation_0-auc:0.97767
# [266]	validation_0-auc:0.97766
# [267]	validation_0-auc:0.97773
# [268]	validation_0-auc:0.97768
# [269]	validation_0-auc:0.97775
# [270]	validation_0-auc:0.97774
# [271]	validation_0-auc:0.97774
# [272]	validation_0-auc:0.97783
# [273]	validation_0-auc:0.97782
# [274]	validation_0-auc:0.97792
# [275]	validation_0-auc:0.97806
# [276]	validation_0-auc:0.97814
# [277]	validation_0-auc:0.97817
# [278]	validation_0-auc:0.97820
# [279]	validation_0-auc:0.97816
# [280]	validation_0-auc:0.97818
# [281]	validation_0-auc:0.97822
# [282]	validation_0-auc:0.97824
# [283]	validation_0-auc:0.97823
# [284]	validation_0-auc:0.97822
# [285]	validation_0-auc:0.97822
# [286]	validation_0-auc:0.97826
# [287]	validation_0-auc:0.97829
# [288]	validation_0-auc:0.97831
# [289]	validation_0-auc:0.97830
# [290]	validation_0-auc:0.97830
# [291]	validation_0-auc:0.97833
# [292]	validation_0-auc:0.97837
# [293]	validation_0-auc:0.97837
# [294]	validation_0-auc:0.97838
# [295]	validation_0-auc:0.97835
# [296]	validation_0-auc:0.97839
# [297]	validation_0-auc:0.97845
# [298]	validation_0-auc:0.97846
# [299]	validation_0-auc:0.97850
# [300]	validation_0-auc:0.97847
# [301]	validation_0-auc:0.97845
# [302]	validation_0-auc:0.97853
# [303]	validation_0-auc:0.97852
# [304]	validation_0-auc:0.97858
# [305]	validation_0-auc:0.97862
# [306]	validation_0-auc:0.97860
# [307]	validation_0-auc:0.97861
# [308]	validation_0-auc:0.97860
# [309]	validation_0-auc:0.97864
# [310]	validation_0-auc:0.97862
# [311]	validation_0-auc:0.97863
# [312]	validation_0-auc:0.97863
# [313]	validation_0-auc:0.97863
# [314]	validation_0-auc:0.97872
# [315]	validation_0-auc:0.97873
# [316]	validation_0-auc:0.97874
# [317]	validation_0-auc:0.97877
# [318]	validation_0-auc:0.97879
# [319]	validation_0-auc:0.97878
# [320]	validation_0-auc:0.97883
# [321]	validation_0-auc:0.97883
# [322]	validation_0-auc:0.97883
# [323]	validation_0-auc:0.97882
# [324]	validation_0-auc:0.97880
# [325]	validation_0-auc:0.97882
# [326]	validation_0-auc:0.97882
# [327]	validation_0-auc:0.97882
# [328]	validation_0-auc:0.97887
# [329]	validation_0-auc:0.97888
# [330]	validation_0-auc:0.97888
# [331]	validation_0-auc:0.97890
# [332]	validation_0-auc:0.97891
# [333]	validation_0-auc:0.97892
# [334]	validation_0-auc:0.97889
# [335]	validation_0-auc:0.97895
# [336]	validation_0-auc:0.97894
# [337]	validation_0-auc:0.97892
# [338]	validation_0-auc:0.97890
# [339]	validation_0-auc:0.97891
# [340]	validation_0-auc:0.97893
# [341]	validation_0-auc:0.97899
# [342]	validation_0-auc:0.97896
# [343]	validation_0-auc:0.97904
# [344]	validation_0-auc:0.97902
# [345]	validation_0-auc:0.97903
# [346]	validation_0-auc:0.97905
# [347]	validation_0-auc:0.97905
# [348]	validation_0-auc:0.97908
# [349]	validation_0-auc:0.97907
# [350]	validation_0-auc:0.97912
# [351]	validation_0-auc:0.97913
# [352]	validation_0-auc:0.97916
# [353]	validation_0-auc:0.97918
# [354]	validation_0-auc:0.97918
# [355]	validation_0-auc:0.97919
# [356]	validation_0-auc:0.97919
# [357]	validation_0-auc:0.97920
# [358]	validation_0-auc:0.97921
# [359]	validation_0-auc:0.97926
# [360]	validation_0-auc:0.97926
# [361]	validation_0-auc:0.97929
# [362]	validation_0-auc:0.97930
# [363]	validation_0-auc:0.97931
# [364]	validation_0-auc:0.97932
# [365]	validation_0-auc:0.97932
# [366]	validation_0-auc:0.97933
# [367]	validation_0-auc:0.97935
# [368]	validation_0-auc:0.97935
# [369]	validation_0-auc:0.97938
# [370]	validation_0-auc:0.97939
# [371]	validation_0-auc:0.97939
# [372]	validation_0-auc:0.97941
# [373]	validation_0-auc:0.97941
# [374]	validation_0-auc:0.97944
# [375]	validation_0-auc:0.97947
# [376]	validation_0-auc:0.97948
# [377]	validation_0-auc:0.97949
# [378]	validation_0-auc:0.97954
# [379]	validation_0-auc:0.97953
# [380]	validation_0-auc:0.97950
# [381]	validation_0-auc:0.97951
# [382]	validation_0-auc:0.97952
# [383]	validation_0-auc:0.97952
# [384]	validation_0-auc:0.97955
# [385]	validation_0-auc:0.97955
# [386]	validation_0-auc:0.97955
# [387]	validation_0-auc:0.97956
# [388]	validation_0-auc:0.97960
# [389]	validation_0-auc:0.97956
# [390]	validation_0-auc:0.97954
# [391]	validation_0-auc:0.97953
# [392]	validation_0-auc:0.97951
# [393]	validation_0-auc:0.97954
# [394]	validation_0-auc:0.97952
# [395]	validation_0-auc:0.97953
# [396]	validation_0-auc:0.97955
# [397]	validation_0-auc:0.97954
# Test ROC AUC: 0.9796

# %%
df_tmp = df_ml_input.copy()
df_tmp["bdtscore2"] = model.predict_proba(X)[:, 1]

def compute_significance(df, cut=0.5):
    s = df[(df["label"] == 1) & (df["bdtscore2"] >= cut)]["weights"].sum()
    b = df[(df["label"] == 0) & (df["bdtscore2"] >= cut)]["weights"].sum()
    return s / np.sqrt(b) if b > 0 else 0, s/df["weights"].sum()

max_sig, acceptance = max(compute_significance(df_tmp, cut) for cut in np.arange(0.0, 0.15, 0.01))
print(f"Max S/√B: {max_sig:.3f}, Acceptance: {acceptance:.3e}")
# Out:
# Max S/√B: 5.251, Acceptance: 4.646e-05

# %%
def binomial_significance(s, b):
    return s / np.sqrt(b) if b > 0 else 0

def s_over_sb(s, b):
    return s / np.sqrt(s + b) if (s + b) > 0 else 0

def s_over_s1p3b(s, b):
    return s / np.sqrt(s + 1.3 * b) if (s + 1.3 * b) > 0 else 0

def scan_significance(df, cut_var="bdtscore2", cut_type="lowercut", cuts=np.arange(0, 0.71, 0.01)):
    sig_sqrtb = []
    sig_sqrt_sb = []
    sig_sqrt_s1p3b = []
    sig_zbi = []

    sigacc_sqrtb = []
    sigacc_sqrt_sb = []
    sigacc_sqrt_s1p3b = []
    sigacc_zbi = []

    acc_values = []

    df_sig = df[df["label"] == 1]
    df_bkg = df[df["label"] == 0]
    total_sig_weight = df_sig["weights"].sum()

    for cut in cuts:
        if cut_type == "lowercut":
            sig_cut = df_sig[df_sig[cut_var] >= cut]
            bkg_cut = df_bkg[df_bkg[cut_var] >= cut]
        elif cut_type == "uppercut":
            sig_cut = df_sig[df_sig[cut_var] <= cut]
            bkg_cut = df_bkg[df_bkg[cut_var] <= cut]
        else:
            raise ValueError("Invalid cut type")

        s = sig_cut["weights"].sum()
        b = bkg_cut["weights"].sum()
        acceptance = s / total_sig_weight if total_sig_weight > 0 else 0

        # Compute significance
        sig1 = binomial_significance(s, b)
        sig2 = s_over_sb(s, b)
        sig3 = s_over_s1p3b(s, b)
        sig4 = zbi(s, b)

        sig_sqrtb.append(sig1)
        sig_sqrt_sb.append(sig2)
        sig_sqrt_s1p3b.append(sig3)
        sig_zbi.append(sig4)

        sigacc_sqrtb.append(sig1 * acceptance)
        sigacc_sqrt_sb.append(sig2 * acceptance)
        sigacc_sqrt_s1p3b.append(sig3 * acceptance)
        sigacc_zbi.append(sig4 * acceptance)

        acc_values.append(acceptance * 100)

    return cuts, acc_values, sig_sqrtb, sig_sqrt_sb, sig_sqrt_s1p3b, sig_zbi, \
           sigacc_sqrtb, sigacc_sqrt_sb, sigacc_sqrt_s1p3b, sigacc_zbi


def plot_significance(cuts, acc, sig1, sig2, sig3, sig4,
                      sigacc1, sigacc2, sigacc3, sigacc4,
                      cut_var, cut_type, save_path):

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

    # Plot Significance
    ax1.plot(cuts, sig1, marker='o', label='S/√B')
    ax1.plot(cuts, sig2, marker='s', label='S/√(S+B)')
    ax1.plot(cuts, sig3, marker='^', label='S/√(S+1.3B)')
    ax1.plot(cuts, sig4, marker='x', label='ZBi')

    ax1.set_ylabel('Significance')
    ax1.set_title(f'Significance vs. {cut_var} ({cut_type})')
    ax1.grid(True)
    ax1.legend()

    # Plot Significance × Acceptance
    ax2.plot(cuts, sigacc1, marker='o', label='(S/√B) × Acc')
    ax2.plot(cuts, sigacc2, marker='s', label='(S/√(S+B)) × Acc')
    ax2.plot(cuts, sigacc3, marker='^', label='(S/√(S+1.3B)) × Acc')
    ax2.plot(cuts, sigacc4, marker='x', label='ZBi × Acc')

    for i, txt in enumerate(acc):
        ax2.text(cuts[i], sigacc1[i], f'{txt:.1f}%', fontsize=8, color='purple', ha='right', va='bottom')

    ax2.set_xlabel(f'{cut_var} Cut')
    ax2.set_ylabel('Significance × Acceptance')
    ax2.set_title(f'Significance × Acceptance vs. {cut_var} ({cut_type})')
    ax2.grid(True)
    ax2.legend()
    ax2.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax2.set_xticks(cuts)
    ax2.set_xticklabels(cuts, rotation=45, ha='right')

    plt.tight_layout()
    plt.savefig(save_path)
    print(f"Saved plot to {save_path}")
    plt.show()


cut_var = "bdtscore2"
cut_type = "lowercut"
cut_values = np.arange(0, 0.6, 0.01)

(cuts, acc, sig1, sig2, sig3, sig4,
 sigacc1, sigacc2, sigacc3, sigacc4) = scan_significance(df_tmp, cut_var, cut_type, cut_values)

plot_significance(
    cuts, acc, sig1, sig2, sig3, sig4,
    sigacc1, sigacc2, sigacc3, sigacc4,
    cut_var=cut_var,
    cut_type=cut_type,
    save_path=f"significance_{cut_var}_{cut_type}.png"
)
# Out:
# Saved plot to significance_bdtscore2_lowercut.png

# %%
wandb.init(project="Dark_ph BDT Grid", reinit=True, resume=False)

param_distributions = {
    'max_depth': randint(3, 15),
    'learning_rate': uniform(0.0001, 0.1),
    'n_estimators': randint(100, 900),
    'subsample': uniform(0.8, 0.2),
    'gamma': uniform(0.1, 1),               # higher = more pruning
}

xgb_clf = XGBClassifier(
    tree_method='hist',
    device='cuda',
    eval_metric=['logloss', 'error', 'auc'],
    early_stopping_rounds=10,
    missing=np.nan,  # Let XGBoost handle any remaining NaNs
    random_state=random_num
)

random_search = RandomizedSearchCV(
    xgb_clf, param_distributions, n_iter=20, scoring='roc_auc', refit=True,
    cv=5, n_jobs=-1, random_state=random_num
)

random_search.fit(X_train, y_train,
          sample_weight=sw_train,
          eval_set=[(X_train, y_train), (X_test, y_test)],
          sample_weight_eval_set=[sw_train, sw_test],
          verbose=False)

best_model = random_search.best_estimator_
wandb.config.update(random_search.best_params_)
wandb.log({"Best CV neg_log_loss": random_search.best_score_})
print("Best parameters found:", random_search.best_params_)

# Generate BDT score predictions for all data
df_ml_input["bdtscore2"] = best_model.predict_proba(df_ml_input.drop(Vars_drop, axis=1))[:, 1]
# df_original["bdtscore2"] = best_model.predict_proba(df_ml_input.drop(Vars_drop, axis=1))[:, 1]

results = best_model.evals_result()
train_loss = results['validation_0']['logloss']
test_loss = results['validation_1']['logloss']
train_error = results['validation_0']['error']
test_error = results['validation_1']['error']
train_auc = results['validation_0']['auc']
test_auc = results['validation_1']['auc']

for i, (train_l, test_l, train_e, test_e, train_a, test_a) in enumerate(zip(train_loss, test_loss, train_error, test_error, train_auc, test_auc)):
    wandb.log({
        "train_logloss": train_l,
        "test_logloss": test_l,
        "train_error": train_e,
        "test_error": test_e,
        "train_auc": train_a,
        "test_auc": test_a,
        "iteration": i
    })

y_train_pred_proba = best_model.predict_proba(X_train)[:, 1]
y_test_pred_proba = best_model.predict_proba(X_test)[:, 1]
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

metrics = {
    "Train LogLoss": log_loss(y_train, y_train_pred_proba, sample_weight=sw_train),
    "Test LogLoss": log_loss(y_test, y_test_pred_proba, sample_weight=sw_test),
    "Train Accuracy": accuracy_score(y_train, y_train_pred),
    "Test Accuracy": accuracy_score(y_test, y_test_pred),
    "Train ROC AUC": roc_auc_score(y_train, y_train_pred_proba, sample_weight=sw_train),
    "Test ROC AUC": roc_auc_score(y_test, y_test_pred_proba, sample_weight=sw_test)
}

wandb.log(metrics)

fpr, tpr, _ = roc_curve(y_test, y_test_pred_proba, sample_weight=sw_test)
tpr_sel = 217.13/374.83
fpr_sel = 5066.37/227609.78
plt.figure(figsize=(7, 7))
plt.plot(fpr, tpr, label="ROC (AUC = {:.3f})".format(metrics["Test ROC AUC"]))
# plt.scatter(fpr_sel, tpr_sel, color='orange', label='cut-flow point')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("roc_randomsearch.png")
wandb.log({"ROC Curve": wandb.Image("roc_randomsearch.png")})
plt.show()

importances = best_model.feature_importances_
indices = np.argsort(importances)
selected_columns = df_ml_input.drop(Vars_drop + ['bdtscore2'], axis=1).columns

plt.figure(figsize=(8, 5))
bars = plt.barh(range(len(selected_columns)), importances[indices], align='center')

# Set y-ticks with feature names
plt.yticks(range(len(selected_columns)), [selected_columns[i] for i in indices])
plt.xlabel('Importance')
plt.title('Feature Importances from the BDT')

# Annotate each bar with the importance value
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width + 0.001, bar.get_y() + bar.get_height()/2,
             f'{width:.3f}', va='center', fontsize=8)

plt.tight_layout()
plt.savefig("feature_importance.png")
wandb.log({"Feature Importance": wandb.Image("feature_importance.png")})
plt.show()


wandb.finish()
# Out:
# Number of event with negative weights : 218306
#             balance      BDTScore          dmet  dphi_met_central_jet  \
# count  2.712769e+06  3.299733e+06  3.299732e+06          2.685312e+06
# mean   3.838187e+00  1.251438e-01 -1.663472e+03          1.404322e+00
# std    6.130255e+00  1.348625e-01  1.103691e+04          1.176454e+00
# min    3.173358e-02 -3.265468e-01 -1.712589e+05          1.192093e-07
# 25%    1.127429e+00  8.068899e-03  0.000000e+00          1.804473e-01
# 50%    1.535997e+00  1.647640e-01  0.000000e+00          1.257375e+00
# 75%    3.771265e+00  2.371679e-01  0.000000e+00          2.651747e+00
# max    2.663229e+02  4.375860e-01  1.246841e+05          3.141592e+00
#
#        dphi_met_phterm       jetterm        metsig     metsigres  \
# count     3.299733e+06  3.299733e+06  3.299733e+06  3.299733e+06
# mean      4.027364e-01  5.232991e+05  1.190690e+01  2.709180e+04
# std       6.314438e-01  7.927709e+05  1.038910e+01  2.307818e+04
# min       0.000000e+00  0.000000e+00  2.269695e-01  8.526343e+03
# 25%       5.094965e-02  3.469025e+04  3.802686e+00  1.057160e+04
# 50%       1.503438e-01  1.292316e+05  1.024574e+01  1.767059e+04
# 75%       4.133940e-01  6.824688e+05  1.590387e+01  3.643209e+04
# max       3.141593e+00  5.019984e+06  2.823775e+02  6.173285e+06
#
#             softerm       weights         label  failJVT_jet_pt1  \
# count  3.299733e+06  3.299733e+06  3.299733e+06    977687.000000
# mean   9.400769e+03  3.916239e-01  1.390112e-03         0.000036
# std    5.880428e+03  7.466398e+00  3.725829e-02         0.000009
# min    0.000000e+00  0.000000e+00  0.000000e+00         0.000017
# 25%    4.993511e+03  1.428430e-03  0.000000e+00         0.000030
# 50%    8.329055e+03  1.519263e-02  0.000000e+00         0.000038
# 75%    1.265224e+04  6.219316e-02  0.000000e+00         0.000044
# max    1.022158e+05  1.221239e+04  1.000000e+00         0.000050
#
#              ph_eta         ph_pt
# count  3.299733e+06  3.299733e+06
# mean   4.619389e+00  5.638744e-06
# std    4.657088e+02  4.934680e-06
# min    3.966429e-01  1.995369e-07
# 25%    7.511125e-01  1.213521e-06
# 50%    1.271312e+00  4.487454e-06
# 75%    2.644231e+00  8.563076e-06
# max    8.314374e+05  1.999992e-05
# Number of nan in each variable:
# balance                  586964
# BDTScore                      0
# dmet                          1
# dphi_met_central_jet     614421
# dphi_met_phterm               0
# jetterm                       0
# metsig                        0
# metsigres                     0
# softerm                       0
# weights                       0
# label                         0
# process                       0
# failJVT_jet_pt1         2322046
# ph_eta                        0
# ph_pt                         0
# dtype: int64
# random number:  69
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/home/jlai/ML/jet_faking/wandb/run-20250617_233026-vveekru7</code>
# Syncing run <strong><a href='https://wandb.ai/dlai211/Dark_ph%20BDT%20Random/runs/vveekru7' target="_blank">elated-star-48</a></strong> to <a href='https://wandb.ai/dlai211/Dark_ph%20BDT%20Random' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dlai211/Dark_ph%20BDT%20Random' target="_blank">https://wandb.ai/dlai211/Dark_ph%20BDT%20Random</a>
#  View run at <a href='https://wandb.ai/dlai211/Dark_ph%20BDT%20Random/runs/vveekru7' target="_blank">https://wandb.ai/dlai211/Dark_ph%20BDT%20Random/runs/vveekru7</a>
# Best parameters found: {'gamma': 0.11128194336438849, 'learning_rate': 0.044589414389065815, 'max_depth': 4, 'n_estimators': 780, 'subsample': 0.8381835043145707}
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Best CV neg_log_loss</td><td>▁</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Test LogLoss</td><td>▁</td></tr><tr><td>Test ROC AUC</td><td>▁</td></tr><tr><td>Train Accuracy</td><td>▁</td></tr><tr><td>Train LogLoss</td><td>▁</td></tr><tr><td>Train ROC AUC</td><td>▁</td></tr><tr><td>iteration</td><td>▁▁▁▁▁▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>test_auc</td><td>▁▁▁▃▃▃▃▃▃▆▆▇████████████████████████████</td></tr><tr><td>test_error</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_logloss</td><td>█▆▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_auc</td><td>▁▄▄▄▄▄▄▅▅▅▅▇▇▇██████████████████████████</td></tr><tr><td>train_error</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_logloss</td><td>█▇▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best CV neg_log_loss</td><td>0.96603</td></tr><tr><td>Test Accuracy</td><td>0.99861</td></tr><tr><td>Test LogLoss</td><td>0.00196</td></tr><tr><td>Test ROC AUC</td><td>0.97853</td></tr><tr><td>Train Accuracy</td><td>0.99861</td></tr><tr><td>Train LogLoss</td><td>0.00186</td></tr><tr><td>Train ROC AUC</td><td>0.98296</td></tr><tr><td>iteration</td><td>395</td></tr><tr><td>test_auc</td><td>0.97847</td></tr><tr><td>test_error</td><td>0.00036</td></tr><tr><td>test_logloss</td><td>0.00196</td></tr><tr><td>train_auc</td><td>0.98313</td></tr><tr><td>train_error</td><td>0.00036</td></tr><tr><td>train_logloss</td><td>0.00186</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-star-48</strong> at: <a href='https://wandb.ai/dlai211/Dark_ph%20BDT%20Random/runs/vveekru7' target="_blank">https://wandb.ai/dlai211/Dark_ph%20BDT%20Random/runs/vveekru7</a><br> View project at: <a href='https://wandb.ai/dlai211/Dark_ph%20BDT%20Random' target="_blank">https://wandb.ai/dlai211/Dark_ph%20BDT%20Random</a><br>Synced 5 W&B file(s), 2 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250617_233026-vveekru7/logs</code>
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:31:07] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:30:55] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:30:53] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:30:53] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:31:13] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:30:56] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:31:14] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /home/jlai/.local/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [23:30:52] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)

# %%
# %%time
X_no_drop = df_ml_input.drop(Vars_drop + ['bdtscore2'], axis=1)

explainer = shap.Explainer(best_model)
shap_values = explainer(X_no_drop)
# Out:
# CPU times: user 12.2 s, sys: 334 ms, total: 12.5 s
# Wall time: 11.4 s

# %%
shap.summary_plot(shap_values, X_no_drop, show=False)
plt.tight_layout()
plt.show()

top_var = X_no_drop.columns[np.abs(shap_values.values).mean(axis=0).argmax()]
shap.dependence_plot(top_var, shap_values.values, X_no_drop, show=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Need to do a feature vs. BDTScore2 2d scatter plot

# %%
corr_features = df_ml_input.drop(Vars_drop + ['bdtscore2'], axis=1)
corr_matrix = corr_features.corr()

# Plot correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0, 
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})
plt.title("Correlation Matrix of Input Variables")
plt.tight_layout()
plt.savefig("correlation_matrix.png")
plt.show()

# %%
def binomial_significance(s, b):
    return s / np.sqrt(b) if b > 0 else 0

def s_over_sb(s, b):
    return s / np.sqrt(s + b) if (s + b) > 0 else 0

def s_over_s1p3b(s, b):
    return s / np.sqrt(s + 1.3 * b) if (s + 1.3 * b) > 0 else 0

def scan_significance(df, cut_var="bdtscore2", cut_type="lowercut", cuts=np.arange(0, 0.71, 0.01)):
    sig_sqrtb = []
    sig_sqrt_sb = []
    sig_sqrt_s1p3b = []
    sig_zbi = []

    sigacc_sqrtb = []
    sigacc_sqrt_sb = []
    sigacc_sqrt_s1p3b = []
    sigacc_zbi = []

    acc_values = []

    df_sig = df[df["label"] == 1]
    df_bkg = df[df["label"] == 0]
    total_sig_weight = df_sig["weights"].sum()

    for cut in cuts:
        if cut_type == "lowercut":
            sig_cut = df_sig[df_sig[cut_var] >= cut]
            bkg_cut = df_bkg[df_bkg[cut_var] >= cut]
        elif cut_type == "uppercut":
            sig_cut = df_sig[df_sig[cut_var] <= cut]
            bkg_cut = df_bkg[df_bkg[cut_var] <= cut]
        else:
            raise ValueError("Invalid cut type")

        s = sig_cut["weights"].sum()
        b = bkg_cut["weights"].sum()
        acceptance = s / total_sig_weight if total_sig_weight > 0 else 0

        # Compute significance
        sig1 = binomial_significance(s, b)
        sig2 = s_over_sb(s, b)
        sig3 = s_over_s1p3b(s, b)
        sig4 = zbi(s, b)

        sig_sqrtb.append(sig1)
        sig_sqrt_sb.append(sig2)
        sig_sqrt_s1p3b.append(sig3)
        sig_zbi.append(sig4)

        sigacc_sqrtb.append(sig1 * acceptance)
        sigacc_sqrt_sb.append(sig2 * acceptance)
        sigacc_sqrt_s1p3b.append(sig3 * acceptance)
        sigacc_zbi.append(sig4 * acceptance)

        acc_values.append(acceptance * 100)

    return cuts, acc_values, sig_sqrtb, sig_sqrt_sb, sig_sqrt_s1p3b, sig_zbi, \
           sigacc_sqrtb, sigacc_sqrt_sb, sigacc_sqrt_s1p3b, sigacc_zbi


def plot_significance(cuts, acc, sig1, sig2, sig3, sig4,
                      sigacc1, sigacc2, sigacc3, sigacc4,
                      cut_var, cut_type, save_path):

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

    # Plot Significance
    ax1.plot(cuts, sig1, marker='o', label='S/√B')
    ax1.plot(cuts, sig2, marker='s', label='S/√(S+B)')
    ax1.plot(cuts, sig3, marker='^', label='S/√(S+1.3B)')
    ax1.plot(cuts, sig4, marker='x', label='ZBi')

    ax1.set_ylabel('Significance')
    ax1.set_title(f'Significance vs. {cut_var} ({cut_type})')
    ax1.grid(True)
    ax1.legend()

    # Plot Significance × Acceptance
    ax2.plot(cuts, sigacc1, marker='o', label='(S/√B) × Acc')
    ax2.plot(cuts, sigacc2, marker='s', label='(S/√(S+B)) × Acc')
    ax2.plot(cuts, sigacc3, marker='^', label='(S/√(S+1.3B)) × Acc')
    ax2.plot(cuts, sigacc4, marker='x', label='ZBi × Acc')

    for i, txt in enumerate(acc):
        ax2.text(cuts[i], sigacc1[i], f'{txt:.1f}%', fontsize=8, color='purple', ha='right', va='bottom')

    ax2.set_xlabel(f'{cut_var} Cut')
    ax2.set_ylabel('Significance × Acceptance')
    ax2.set_title(f'Significance × Acceptance vs. {cut_var} ({cut_type})')
    ax2.grid(True)
    ax2.legend()
    ax2.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax2.set_xticks(cuts)
    ax2.set_xticklabels(cuts, rotation=45, ha='right')

    plt.tight_layout()
    plt.savefig(save_path)
    print(f"Saved plot to {save_path}")
    plt.show()


cut_var = "bdtscore2"
cut_type = "lowercut"
cut_values = np.arange(0, 0.31, 0.01)

(cuts, acc, sig1, sig2, sig3, sig4,
 sigacc1, sigacc2, sigacc3, sigacc4) = scan_significance(df_ml_input, cut_var, cut_type, cut_values)

plot_significance(
    cuts, acc, sig1, sig2, sig3, sig4,
    sigacc1, sigacc2, sigacc3, sigacc4,
    cut_var=cut_var,
    cut_type=cut_type,
    save_path=f"significance_{cut_var}_{cut_type}.png"
)
# Out:
# Saved plot to significance_bdtscore2_lowercut.png

# %%
bdtscore2_cut = 0.03
signal_bdtscore2_cut = df_ml_input[(df_ml_input.label==1) & (df_ml_input.bdtscore2 >= bdtscore2_cut)]['weights'].sum()
bkg_bdtscore2_cut = df_ml_input[(df_ml_input.label==0) & (df_ml_input.bdtscore2 >= bdtscore2_cut)]['weights'].sum()
signal_bdtscore2_cut / np.sqrt(bkg_bdtscore2_cut)
# Out:
# 3.5712887443228527

# %%
from collections import Counter
ntuple_names = list(Counter(df.process).keys())
ntuple_names, corr_features.columns

# %%
df_ml_input
# Out:
#             metsig         met   met_noJVT       dmet  dphi_met_phterm  \
# 0         2.761993  106920.875  106920.875      0.000         0.938348
# 1         8.542773  102183.560  102183.560      0.000         1.180506
# 2         6.480173  113106.060  113106.060      0.000         1.881112
# 3         5.958667  131013.914  131013.914      0.000         1.852292
# 4         2.547094  125378.336  125378.336      0.000         0.323595
# ...            ...         ...         ...        ...              ...
# 2049424  10.568502  126600.290  126600.290      0.000         0.185933
# 2049425   5.365795  141435.140  141435.140      0.000         0.059292
# 2049426   2.178480  101984.164  115113.266  13129.102         0.709207
# 2049427   4.565784  127682.870  127682.870      0.000         0.777370
# 2049428   9.710623  114377.625   94429.664 -19947.960         0.212270
#
#          dphi_ph_centraljet1  dphi_phterm_jetterm     jetterm  \
# 0                   2.772006             1.602420   84722.190
# 1                   1.609753             1.609753   86744.400
# 2                   2.767581             2.523243  186978.030
# 3                   2.392476             2.202219  176778.980
# 4                   1.838230             0.870069   49163.324
# ...                      ...                  ...         ...
# 2049424                  NaN             0.818441   30344.678
# 2049425             1.818364             2.981917   86980.640
# 2049426             2.599164             1.334559   79711.680
# 2049427             2.256948             1.055964  192884.890
# 2049428                  NaN             0.996322   34168.120
#
#          dphi_met_central_jet  BDTScore  ...  label  process metsigres  \
# 0                    1.307934  0.131412  ...      1   ggHyyd  0.000026
# 1                    2.712346  0.151073  ...      1   ggHyyd  0.000084
# 2                    2.255124  0.326790  ...      1   ggHyyd  0.000057
# 3                    2.601409  0.267467  ...      1   ggHyyd  0.000045
# 4                    1.626958  0.189026  ...      1   ggHyyd  0.000020
# ...                       ...       ...  ...    ...      ...       ...
# 2049424                   NaN  0.219619  ...      0   data23  0.000083
# 2049425              1.382520  0.134930  ...      0   data23  0.000038
# 2049426              0.166778  0.191354  ...      0   data23  0.000021
# 2049427              1.662015  0.194030  ...      0   data23  0.000036
# 2049428                   NaN  0.112181  ...      0   data23  0.000085
#
#             ph_pt     ph_eta  dphi_met_jetterm  failJVT_jet_pt1  \
# 0        0.000015   1.116581          1.505859         0.000046
# 1        0.000019   7.054524          2.329661              NaN
# 2        0.000008   0.618951          1.557315              NaN
# 3        0.000015   0.500710          2.857742         0.000029
# 4        0.000011   0.438361          1.829915              NaN
# ...           ...        ...               ...              ...
# 2049424  0.000010   0.558637          1.581007              NaN
# 2049425  0.000004   0.589414          0.342158              NaN
# 2049426  0.000016   0.564312          1.599099         0.000049
# 2049427  0.000019  30.790111          3.589457         0.000023
# 2049428  0.000010   7.837664          1.275425         0.000040
#
#          n_jet_central   dphi_jj  bdtscore2
# 0             1.000000       NaN   0.000743
# 1             1.000000       NaN   0.302019
# 2             0.333333 -3.187578   0.034247
# 3             0.333333 -0.461536   0.006765
# 4             0.500000 -0.374474   0.000042
# ...                ...       ...        ...
# 2049424            NaN       NaN   0.000102
# 2049425       0.500000  0.491530   0.000028
# 2049426       0.333333 -0.350241   0.000042
# 2049427       0.333333 -1.258064   0.000580
# 2049428            NaN       NaN   0.000288
#
# [2049429 rows x 21 columns]

# %%
# Copy full df_ml_input
df_restored = df_ml_input.copy()

# Revert Vars3: 1/x → x, handle division by zero and inf
df_restored[Vars3] = 1 / df_restored[Vars3]
df_restored[Vars3].replace([np.inf, -np.inf], np.nan, inplace=True)

# Replace NaN with -999 only for Vars2 and Vars3
df_restored[Vars2] = df_restored[Vars2].fillna(-999)
df_restored[Vars3] = df_restored[Vars3].fillna(-999)

df_restored
# Out:
#             metsig         met   met_noJVT       dmet  dphi_met_phterm  \
# 0         2.761993  106920.875  106920.875      0.000         0.938348
# 1         8.542773  102183.560  102183.560      0.000         1.180506
# 2         6.480173  113106.060  113106.060      0.000         1.881112
# 3         5.958667  131013.914  131013.914      0.000         1.852292
# 4         2.547094  125378.336  125378.336      0.000         0.323595
# ...            ...         ...         ...        ...              ...
# 2049424  10.568502  126600.290  126600.290      0.000         0.185933
# 2049425   5.365795  141435.140  141435.140      0.000         0.059292
# 2049426   2.178480  101984.164  115113.266  13129.102         0.709207
# 2049427   4.565784  127682.870  127682.870      0.000         0.777370
# 2049428   9.710623  114377.625   94429.664 -19947.960         0.212270
#
#          dphi_ph_centraljet1  dphi_phterm_jetterm     jetterm  \
# 0                   2.772006             1.602420   84722.190
# 1                   1.609753             1.609753   86744.400
# 2                   2.767581             2.523243  186978.030
# 3                   2.392476             2.202219  176778.980
# 4                   1.838230             0.870069   49163.324
# ...                      ...                  ...         ...
# 2049424          -999.000000             0.818441   30344.678
# 2049425             1.818364             2.981917   86980.640
# 2049426             2.599164             1.334559   79711.680
# 2049427             2.256948             1.055964  192884.890
# 2049428          -999.000000             0.996322   34168.120
#
#          dphi_met_central_jet  BDTScore  ...  label  process  metsigres  \
# 0                    1.307934  0.131412  ...      1   ggHyyd  38711.496
# 1                    2.712346  0.151073  ...      1   ggHyyd  11961.404
# 2                    2.255124  0.326790  ...      1   ggHyyd  17454.174
# 3                    2.601409  0.267467  ...      1   ggHyyd  21987.120
# 4                    1.626958  0.189026  ...      1   ggHyyd  49224.080
# ...                       ...       ...  ...    ...      ...        ...
# 2049424           -999.000000  0.219619  ...      0   data23  11979.019
# 2049425              1.382520  0.134930  ...      0   data23  26358.656
# 2049426              0.166778  0.191354  ...      0   data23  46814.360
# 2049427              1.662015  0.194030  ...      0   data23  27965.160
# 2049428           -999.000000  0.112181  ...      0   data23  11778.608
#
#               ph_pt    ph_eta  dphi_met_jetterm  failJVT_jet_pt1  \
# 0         64725.300  0.895591          0.664073     21859.162109
# 1         52631.047  0.141753          0.429247      -999.000000
# 2        122266.780  1.615636          0.642131      -999.000000
# 3         66120.305  1.997163          0.349927     33962.769531
# 4         88218.914  2.281224          0.546473      -999.000000
# ...             ...       ...               ...              ...
# 2049424   97204.280  1.790071          0.632508      -999.000000
# 2049425  234519.170  1.696600          2.922626      -999.000000
# 2049426   63802.973  1.772069          0.625352     20442.738281
# 2049427   52470.840  0.032478          0.278594     42927.753906
# 2049428   99967.890  0.127589          0.784052     24926.392578
#
#          n_jet_central     dphi_jj   weights
# 0                  1.0 -999.000000  0.074079
# 1                  1.0 -999.000000  0.116076
# 2                  3.0   -0.313718  0.119337
# 3                  3.0   -2.166679  0.115276
# 4                  2.0   -2.670413  0.119649
# ...                ...         ...       ...
# 2049424         -999.0 -999.000000  1.990000
# 2049425            2.0    2.034463  1.990000
# 2049426            3.0   -2.855174  1.990000
# 2049427            3.0   -0.794872  1.840000
# 2049428         -999.0 -999.000000  1.840000
#
# [2049429 rows x 21 columns]

# %%
signal_name = 'ggHyyd'  # Define signal dataset
cut_name = 'ml'

for cut_var_tmp in corr_features.columns:
    var_config = getVarDict(signal_name, 'ggHyyd', var_name=cut_var_tmp)
    
    for var in var_config:
        # print(var)
        bg_values = []     
        bg_weights = []    
        bg_colors = []     
        bg_labels = []     
    
        signal_values = [] 
        signal_weights = []
        signal_color = None 
        signal_label = None
    
        for j in range(len(ntuple_names)):
            process = ntuple_names[j]
            df_tmp = df_restored[df_restored.process == process]
            df_tmp = df_tmp.replace(np.nan, -999)
            df_tmp = df_tmp[df_tmp.bdtscore2 > 0.04]
            
            x = df_tmp[var]
            bins = var_config[var]['bins'] 
            weights = df_tmp['weights']
            
            sample_info = sample_dict[process]
            color = sample_info['color']
            legend = sample_info['legend']
    
            
            if process == 'ggHyyd':  # signal
                signal_values.append(x)
                signal_weights.append(weights)
                signal_color = color
                signal_label = legend
            else:   # background
                bg_values.append(x)
                bg_weights.append(weights)
                bg_colors.append(color)
                bg_labels.append(legend)
    
        fig, (ax_top, ax_bot) = plt.subplots(2, 1, figsize=(12, 13), gridspec_kw={'height_ratios': [9, 4]})
    
        ax_top.hist(bg_values, bins=bins, weights=bg_weights, color=bg_colors,
                    label=bg_labels, stacked=True)
    
        ax_top.hist(signal_values, bins=bins, weights=signal_weights, color=signal_color,
                    label=signal_label, histtype='step', linewidth=2)
    
        signal_all = np.concatenate(signal_values) if len(signal_values) > 0 else np.array([])
        signal_weights_all = np.concatenate(signal_weights) if len(signal_weights) > 0 else np.array([])
    
        # Add error bar for signal (top plot)
        if len(signal_all) > 0:
            signal_counts, bin_edges = np.histogram(signal_all, bins=bins, weights=signal_weights_all)
            sum_weights_sq, _ = np.histogram(signal_all, bins=bins, weights=signal_weights_all**2)
            bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
            signal_errors = np.sqrt(sum_weights_sq)  # Poisson error sqrt(N)
    
            ax_top.errorbar(bin_centers, signal_counts, yerr=signal_errors, fmt='.', linewidth=2,
                            color=signal_color, capsize=0)
    
        ax_top.set_yscale('log')
        ax_top.set_ylim(0.0001, 1e11)
        ax_top.set_xlim(bins[0], bins[-1])
        ax_top.minorticks_on()
        ax_top.grid(True, which="both", linestyle="--", linewidth=0.5)
        ax_top.set_ylabel("Events")
        ax_top.legend(ncol=2)
        # ax_top.set_title("vtx_sumPt distribution")
    
        bg_all = np.concatenate(bg_values) if len(bg_values) > 0 else np.array([])
        bg_weights_all = np.concatenate(bg_weights) if len(bg_weights) > 0 else np.array([])
    
        # Compute the weighted histogram counts using np.histogram
        S_counts, _ = np.histogram(signal_all, bins=bins, weights=signal_weights_all)
        B_counts, _ = np.histogram(bg_all, bins=bins, weights=bg_weights_all)     
    
        # Compute per-bin significance
        sig_simple = np.zeros_like(S_counts, dtype=float)
        sig_s_plus_b = np.zeros_like(S_counts, dtype=float)
        sig_s_plus_1p3b = np.zeros_like(S_counts, dtype=float)
    
        sqrt_B = np.sqrt(B_counts)
        sqrt_SplusB = np.sqrt(S_counts + B_counts)
        sqrt_Splus1p3B = np.sqrt(S_counts + 1.3 * B_counts)
    
        # Avoid division by zero safely
        sig_simple = np.where(B_counts > 0, S_counts / sqrt_B, 0)
        sig_s_plus_b = np.where((S_counts + B_counts) > 0, S_counts / sqrt_SplusB, 0)
        sig_s_plus_1p3b = np.where((S_counts + 1.3 * B_counts) > 0, S_counts / sqrt_Splus1p3B, 0)
    
        # Add Binomial ExpZ per bin
        zbi_per_bin = np.array([
            zbi(S_counts[i], B_counts[i], sigma_b_frac=0.3)
            for i in range(len(S_counts))
        ])
    
        # Compute the bin centers for plotting
        bin_centers = 0.5 * (bins[:-1] + bins[1:])
    
        # Compute the total significance: total S / sqrt(total B)
        total_signal = np.sum(S_counts)
        total_bkg = np.sum(B_counts)
    
        if total_bkg > 0:
            total_sig_simple = total_signal / np.sqrt(total_bkg)
            total_sig_s_plus_b = total_signal / np.sqrt(total_signal + total_bkg)
            total_sig_s_plus_1p3b = total_signal / np.sqrt(total_signal + 1.3 * total_bkg)
            total_sig_binomial = zbi(total_signal, total_bkg, sigma_b_frac=0.3)
        else:
            total_sig_simple = total_sig_s_plus_b = total_sig_s_plus_1p3b = total_sig_binomial = 0
    
        # --- Plot all significance curves ---
        ax_bot.step(bin_centers, sig_simple, where='mid', color='chocolate', linewidth=2,
                    label=f"S/√B = {total_sig_simple:.4f}")
        ax_bot.step(bin_centers, sig_s_plus_b, where='mid', color='tomato', linewidth=2,
                    label=f"S/√(S+B) = {total_sig_s_plus_b:.4f}")
        ax_bot.step(bin_centers, sig_s_plus_1p3b, where='mid', color='orange', linewidth=2,
                    label=f"S/√(S+1.3B) = {total_sig_s_plus_1p3b:.4f}")
        ax_bot.step(bin_centers, zbi_per_bin, where='mid', color='plum', linewidth=2,
                    label=f"Binomial ExpZ = {total_sig_binomial:.4f}")
    
        ax_bot.set_xlabel(var_config[var]['title'])
        # ax_bot.set_xticks(np.linspace(bins[0], bins[-1], 11))
        ax_bot.set_ylabel("Significance")
        ax_bot.set_ylim(-0.8, 2)
        ax_top.set_xlim(bins[0], bins[-1])
    
        # Do not set a title on the bottom plot.
        ax_bot.set_title("")
    
        # Draw a legend with purple text.
        leg = ax_bot.legend()
        for text in leg.get_texts():
            text.set_color('purple')
    
        plt.xlim(bins[0], bins[-1])
        plt.tight_layout()
        plt.savefig(f"/data/jlai/dark_photon/jets_faking_photons/lumi135/mc23d_{cut_name}cut/{var}_nodijet.png")
        print(f"successfully saved to /data/jlai/dark_photon/jets_faking_photons/lumi135/mc23d_{cut_name}cut/{var}_nodijet.png")
        plt.close()
        # plt.show()
    
        y_true = np.concatenate([np.ones_like(signal_all), np.zeros_like(bg_all)])
        # Use the vtx_sumPt values as the classifier output.
        y_scores = np.concatenate([signal_all, bg_all])
        # Combine the weights for all events.
        y_weights = np.concatenate([signal_weights_all, bg_weights_all])
    
        # Compute the weighted ROC curve.
        fpr, tpr, thresholds = roc_curve(y_true, y_scores, sample_weight=y_weights)
        sorted_indices = np.argsort(fpr)
        fpr_sorted = fpr[sorted_indices]
        tpr_sorted = tpr[sorted_indices]
    
        roc_auc = auc(fpr_sorted, tpr_sorted)
    
        # Create a new figure for the ROC curve.
        plt.figure(figsize=(8, 8))
        plt.plot(fpr, tpr, lw=2, color='red', label=f'ROC curve (AUC = {roc_auc:.5f})')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random chance')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve for {var}")
        plt.legend(loc="lower right")
        plt.grid(True, which="both", linestyle="--", linewidth=0.5)
        plt.tight_layout()    
        plt.savefig(f"/data/jlai/dark_photon/jets_faking_photons/lumi135/mc23d_{cut_name}cut/roc_curve_{var}.png")
        print(f"successfully saved to /data/jlai/dark_photon/jets_faking_photons/lumi135/mc23d_{cut_name}cut/roc_curve_{var}.png")
        plt.close()
        # plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_63/3201588613.py in ?()
#      20         signal_weights = []
#      21         signal_color = None
#      22         signal_label = None
#      23
# ---> 24         for j in range(len(ntuple_names)):
#      25             process = ntuple_names[j]
#      26             df_tmp = df_ml_input[df_ml_input.process == process]
#      27             df_tmp = df_tmp.replace(np.nan, -999)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'bdtscore2'

# %%
ntuple_names
# Out:
# ['ggHyyd', 'Zjets', 'Zgamma', 'Wgamma', 'Wjets', 'gammajet_direct', 'data23']

# %%
for i in range(len(ntuple_names)):
    process = ntuple_names[i]
    df_tmp = df_ml_input[df_ml_input.process == process]
    df_tmp = df_tmp.replace(np.nan, -999)
    df_tmp = df_tmp[df_tmp.bdtscore2 > 0.04]
    print(process, sum(df_tmp['weights']))
# Out:
# ggHyyd 169.48022278277514
# Zjets 1.5359084282390538
# Zgamma 413.8146102406148
# Wgamma 796.5183094105563
# Wjets 647.6491024978909
# gammajet_direct 32.70923339631871
# data23 148.01000000000005

# %%
df_ml_input[df_ml_input.process == "data23"]
# Out:
#             metsig         met   met_noJVT       dmet  dphi_met_phterm  \
# 1988154  10.955925  108363.850  108363.850      0.000         0.417533
# 1988155   4.961036  138918.060  138918.060      0.000         1.095190
# 1988156   8.525230  130261.350  130261.350      0.000         0.784904
# 1988157   9.532713  107069.984  107069.984      0.000         1.494578
# 1988158   6.830176  138277.220  138277.220      0.000         0.139828
# ...            ...         ...         ...        ...              ...
# 2049390  10.568502  126600.290  126600.290      0.000         0.185933
# 2049391   5.365795  141435.140  141435.140      0.000         0.059292
# 2049392   2.178480  101984.164  115113.266  13129.102         0.709207
# 2049393   4.565784  127682.870  127682.870      0.000         0.777370
# 2049394   9.710623  114377.625   94429.664 -19947.960         0.212270
#
#          dphi_ph_centraljet1  dphi_phterm_jetterm     jetterm  \
# 1988154             2.150074             1.535044   59350.066
# 1988155                  NaN             1.657376  117127.860
# 1988156             1.593890             1.720349   82149.410
# 1988157                  NaN             2.147708  140849.300
# 1988158                  NaN             0.499228   76565.230
# ...                      ...                  ...         ...
# 2049390                  NaN             0.818441   30344.678
# 2049391             1.818364             2.981917   86980.640
# 2049392             2.599164             1.334559   79711.680
# 2049393             2.256948             1.055964  192884.890
# 2049394                  NaN             0.996322   34168.120
#
#          dphi_met_central_jet  BDTScore  ...  label  process metsigres  \
# 1988154              1.409052  0.122659  ...      0   data23  0.000101
# 1988155                   NaN  0.277765  ...      0   data23  0.000036
# 1988156              0.762798  0.215109  ...      0   data23  0.000065
# 1988157                   NaN  0.193171  ...      0   data23  0.000089
# 1988158                   NaN  0.204901  ...      0   data23  0.000049
# ...                       ...       ...  ...    ...      ...       ...
# 2049390                   NaN  0.219619  ...      0   data23  0.000083
# 2049391              1.382520  0.134930  ...      0   data23  0.000038
# 2049392              0.166778  0.191354  ...      0   data23  0.000021
# 2049393              1.662015  0.194030  ...      0   data23  0.000036
# 2049394                   NaN  0.112181  ...      0   data23  0.000085
#
#             ph_pt     ph_eta  dphi_met_jetterm  failJVT_jet_pt1  \
# 1988154  0.000011   1.576624          0.894846         0.000038
# 1988155  0.000014   0.833625          1.778774         0.000040
# 1988156  0.000010  25.607277          1.069011              NaN
# 1988157  0.000013   1.380487          1.531089              NaN
# 1988158  0.000015   9.220017          2.782415              NaN
# ...           ...        ...               ...              ...
# 2049390  0.000010   0.558637          1.581007              NaN
# 2049391  0.000004   0.589414          0.342158              NaN
# 2049392  0.000016   0.564312          1.599099         0.000049
# 2049393  0.000019  30.790111          3.589457         0.000023
# 2049394  0.000010   7.837664          1.275425         0.000040
#
#          n_jet_central  dphi_jj  bdtscore2
# 1988154       0.500000      NaN   0.000026
# 1988155       0.333333      NaN   0.000038
# 1988156       0.500000      NaN   0.000041
# 1988157       1.000000      NaN   0.000154
# 1988158       0.500000      NaN   0.000055
# ...                ...      ...        ...
# 2049390            NaN      NaN   0.000063
# 2049391       0.500000      NaN   0.000020
# 2049392       0.333333      NaN   0.000027
# 2049393       0.333333      NaN   0.000081
# 2049394            NaN      NaN   0.000088
#
# [61241 rows x 21 columns]

# %%
csv_dict = {
    'ggHyyd': pd.read_csv('signal.csv'),
    'Wgamma': pd.read_csv('wgamma.csv'),
    'Zgamma': pd.read_csv('zgamma.csv'),
    # ... Add more background processes here
}

sample_dict = {
    'ggHyyd': {'color': 'red', 'legend': 'Signal'},
    'Wgamma': {'color': 'blue', 'legend': 'Wγ'},
    'Zgamma': {'color': 'green', 'legend': 'Zγ'},
}

cut_name = 'ml'
signal_name = 'ggHyyd'
common_weights_column = 'weights'

# Columns to loop over
for var in corr_features.columns:
    bins = np.histogram_bin_edges(
        np.concatenate([df[var].dropna().values for df in csv_dict.values()]),
        bins=20
    )

    bg_values, bg_weights, bg_colors, bg_labels = [], [], [], []
    signal_values, signal_weights = [], []
    signal_color, signal_label = None, None

    for process, df in csv_dict.items():
        x = df[var].values
        w = df[common_weights_column].values
        info = sample_dict[process]

        if process == signal_name:
            signal_values.append(x)
            signal_weights.append(w)
            signal_color = info['color']
            signal_label = info['legend']
        else:
            bg_values.append(x)
            bg_weights.append(w)
            bg_colors.append(info['color'])
            bg_labels.append(info['legend'])

    # === Plotting code identical to before ===
    fig, (ax_top, ax_bot) = plt.subplots(2, 1, figsize=(12, 13), gridspec_kw={'height_ratios': [9, 4]})
    ax_top.hist(bg_values, bins=bins, weights=bg_weights, color=bg_colors, label=bg_labels, stacked=True)
    ax_top.hist(signal_values, bins=bins, weights=signal_weights, color=signal_color,
                label=signal_label, histtype='step', linewidth=2)

    signal_all = np.concatenate(signal_values)
    signal_weights_all = np.concatenate(signal_weights)
    bg_all = np.concatenate(bg_values)
    bg_weights_all = np.concatenate(bg_weights)

    # Signal error bars
    signal_counts, bin_edges = np.histogram(signal_all, bins=bins, weights=signal_weights_all)
    sum_weights_sq, _ = np.histogram(signal_all, bins=bins, weights=signal_weights_all**2)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    signal_errors = np.sqrt(sum_weights_sq)
    ax_top.errorbar(bin_centers, signal_counts, yerr=signal_errors, fmt='.', linewidth=2,
                    color=signal_color, capsize=0)

    ax_top.set_yscale('log')
    ax_top.set_ylim(0.0001, 1e11)
    ax_top.set_xlim(bins[0], bins[-1])
    ax_top.set_ylabel("Events")
    ax_top.grid(True, which="both", linestyle="--", linewidth=0.5)
    ax_top.legend(ncol=2)

    # --- Significance ---
    B_counts, _ = np.histogram(bg_all, bins=bins, weights=bg_weights_all)
    S_counts, _ = np.histogram(signal_all, bins=bins, weights=signal_weights_all)

    sig_simple = np.where(B_counts > 0, S_counts / np.sqrt(B_counts), 0)
    sig_s_plus_b = np.where((S_counts + B_counts) > 0, S_counts / np.sqrt(S_counts + B_counts), 0)
    sig_s_plus_1p3b = np.where((S_counts + 1.3 * B_counts) > 0, S_counts / np.sqrt(S_counts + 1.3 * B_counts), 0)
    zbi_per_bin = np.array([zbi(S_counts[i], B_counts[i]) for i in range(len(S_counts))])

    total_signal = np.sum(S_counts)
    total_bkg = np.sum(B_counts)
    total_sig_simple = total_signal / np.sqrt(total_bkg) if total_bkg > 0 else 0
    total_sig_s_plus_b = total_signal / np.sqrt(total_signal + total_bkg) if total_bkg > 0 else 0
    total_sig_s_plus_1p3b = total_signal / np.sqrt(total_signal + 1.3 * total_bkg) if total_bkg > 0 else 0
    total_sig_binomial = zbi(total_signal, total_bkg)

    ax_bot.step(bin_centers, sig_simple, where='mid', color='chocolate', linewidth=2,
                label=f"S/√B = {total_sig_simple:.4f}")
    ax_bot.step(bin_centers, sig_s_plus_b, where='mid', color='tomato', linewidth=2,
                label=f"S/√(S+B) = {total_sig_s_plus_b:.4f}")
    ax_bot.step(bin_centers, sig_s_plus_1p3b, where='mid', color='orange', linewidth=2,
                label=f"S/√(S+1.3B) = {total_sig_s_plus_1p3b:.4f}")
    ax_bot.step(bin_centers, zbi_per_bin, where='mid', color='plum', linewidth=2,
                label=f"Binomial ExpZ = {total_sig_binomial:.4f}")

    ax_bot.set_xlabel(var)
    ax_bot.set_ylabel("Significance")
    ax_bot.set_ylim(-0.8, 2)
    ax_bot.legend()
    ax_bot.grid(True, which="both", linestyle="--", linewidth=0.5)

    plt.tight_layout()
    plt.savefig(f"../jets_faking_photons/lumi135/mc23d_{cut_name}cut/{var}_nodijet.png")
    print(f"Saved: {var}_nodijet.png")
    plt.close()

    # ROC curve
    y_true = np.concatenate([np.ones_like(signal_all), np.zeros_like(bg_all)])
    y_scores = np.concatenate([signal_all, bg_all])
    y_weights = np.concatenate([signal_weights_all, bg_weights_all])

    fpr, tpr, _ = roc_curve(y_true, y_scores, sample_weight=y_weights)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, lw=2, color='red', label=f'ROC curve (AUC = {roc_auc:.5f})')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random chance')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve for {var}")
    plt.legend(loc="lower right")
    plt.grid(True, linestyle="--", linewidth=0.5)
    plt.tight_layout()
    plt.savefig(f"../jets_faking_photons/lumi135/mc23d_{cut_name}cut/roc_curve_{var}.png")
    print(f"Saved: roc_curve_{var}.png")
    plt.close()
